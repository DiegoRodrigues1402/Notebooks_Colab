# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoRodrigues1402/Notebooks_Colab/blob/main/tabela_onu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados_imdb = pd.read_xml('/content/imdb_top_1000.xml')

# %%
dados_imdb
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %%
lista_hab = pd.read_html('/content/lista_habitantes.htm')

# %%
nova= lista_hab[0]

# %%
nova
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 429 921 746
# 1           NaN       2                              China     1 426 391 281
# 2           NaN       3                     Estados Unidos       339 987 103
# 3           NaN       4                          Indonésia       277 184 719
# 4           NaN       5                          Paquistão       240 215 932
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)               806
# 246         NaN     195                           Vaticano               801
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               573
# 248         NaN       –     Tristão da Cunha (Reino Unido)               241
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                40
#
#      Data      Estimativa Oficial
# ...

# %%
nova['Estimativa da ONU']
# Out:
# 0      1 429 921 746
# 1      1 426 391 281
# 2        339 987 103
# 3        277 184 719
# 4        240 215 932
#            ...
# 245              806
# 246              801
# 247              573
# 248              241
# 249               40
# Name: Estimativa da ONU, Length: 250, dtype: object
