# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoRodrigues1402/Notebooks_Colab/blob/main/lista_ordem_tipo_imovel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
dados = {
  "nome": "João",
  "idade": 28,
  "enderecos": [
    {
      "tipo": "casa",
      "rua": "Rua A",
      "numero": 123,
      "cidade": "São Paulo"
    },
    {
      "tipo": "trabalho",
      "rua": "Rua B",
      "numero": 456,
      "cidade": "Rio de Janeiro"
    }
  ]
}

# %%
pd.json_normalize(dados ,record_path='enderecos',meta=["nome","idade"],errors='ignore')
# Out:
#        tipo    rua  numero          cidade  nome idade
# 0      casa  Rua A     123       São Paulo  João    28
# 1  trabalho  Rua B     456  Rio de Janeiro  João    28
